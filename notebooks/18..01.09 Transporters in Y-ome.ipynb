# %%
import json
import pandas as pd
import numpy as np
from yome import Session
from yome.models import *
from yome.util import to_df, report
import re
from sqlalchemy import or_, and_
from sqlalchemy.orm import aliased
import itertools as it
import seaborn as sns

# %%
from mpl_recipes import mpl_setup
# %mpl_setup
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
session = Session()

# %%
report(session, 'b3026')
# Out:
# locus_id        b3026
# primary_name     qseC
# Name: 0, dtype: object
# <style  type="text/css" >
#     #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row0_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row1_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row2_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row3_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row4_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row5_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row6_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row7_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row8_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row9_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row10_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row11_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row12_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row13_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row14_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row15_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row16_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row17_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row18_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row19_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row20_col0 {
#             text-align:  left;
#         }    #T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row21_col0 {
#             text-align:  left;
#         }</style>
# <table id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >feature</th>
#     </tr>    <tr>
#         <th class="index_name level0" >knowledgebase_name</th>
#         <th class="index_name level1" >feature_type</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level0_row0" class="row_heading level0 row0" rowspan=8>EcoCyc (high)</th>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row0" class="row_heading level1 row0" >description</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row0_col0" class="data row0 col0" >sensory histidine kinase QseC</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row1" class="row_heading level1 row1" >summary_html</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row1_col0" class="data row1 col0" >SummaryQseC is the sensor kinase component of the QseB-QseC two-component system, which is one component of the quorum-sensing regulatory cascade involved in the regulation of flagella and motility genes.  QseBC modulates transcription of flhDC, the master regulator for flagella and motility genes [Sperandio02].A transposon insertion mutant in qseC is more susceptible to pyrazinoic acid [Schaller02]; qseBC mutants show hypersensitivity to several toxic cations [Zhou03b].qseC: "quorum-sensing E. coli regulator C" [Sperandio02]A site for RbsR in negatively controlling the qseC gene was identified based on genomic Selex analysis with the absolute center positions in the genome at position 3168522.5 and with the palindromic octanucleotide sequence TTtAcccAACGTcTtaGTcT [Shimada13b].  Additional Citations:
# [Clarke05]  </td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row2" class="row_heading level1 row2" >product_type</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row2_col0" class="data row2 col0" >polypeptide</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row3" class="row_heading level1 row3" >reaction_equation</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row3_col0" class="data row3 col0" >QseC + ATP  →  sensory histidine kinase QseC - phosphorylated + ADP</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row4" class="row_heading level1 row4" >is_pseudogene</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row4_col0" class="data row4 col0" >f</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row5" class="row_heading level1 row5" >is_phantom_gene</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row5_col0" class="data row5 col0" >f</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row6" class="row_heading level1 row6" >evidence_html</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row6_col0" class="data row6 col0" >
#
#
#
#
# Inferred from expression pattern [Sperandio02]Human inference of function from sequence [Sperandio02]
#
# </td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row7" class="row_heading level1 row7" >is_insertion_element</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row7_col0" class="data row7 col0" >f</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level0_row8" class="row_heading level0 row8" rowspan=5>EcoGene (tbd)</th>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row8" class="row_heading level1 row8" >protein</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row8_col0" class="data row8 col0" >quorum sensing sensory histidine kinase in two-component regulatory system with QseB</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row9" class="row_heading level1 row9" >function</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row9_col0" class="data row9 col0" >Null</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row10" class="row_heading level1 row10" >description</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row10_col0" class="data row10 col0" >Quorum sensing two-component sensor kinase; cognate to QseB response regulator; regulates flagella synthesis and motilty by activating transcription of flhDC; responds to AI-3 and </td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row11" class="row_heading level1 row11" >comments</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row11_col0" class="data row11 col0" >Characterized in an EHEC strain, QseC has been shown to respond and bind to AI-3 and AI-3-cross signaling human hormones epinephrine and norepinephrine (Clarke, 2006). A mutant qseC confers sensitivity to pyrazinoic acid.</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row12" class="row_heading level1 row12" >is_pseudogene</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row12_col0" class="data row12 col0" >f</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level0_row13" class="row_heading level0 row13" rowspan=7>UniProt (high)</th>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row13" class="row_heading level1 row13" >upid</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row13_col0" class="data row13 col0" >P40719</td>
#     </tr>    <tr>
#         <th id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82level1_row14" class="row_heading level1 row14" >protein</th>
#         <td id="T_9fb7d39e_006d_11e8_b697_406c8fbb9e82row14_col0" class="data row14 col0" >Sensor protein QseC (

# %% [markdown]
# # Load putative transporter list from ecocyc

# %%
ec_putative_transporters = pd.read_table('../sources/ecocyc/ecocyc-putative-inner-membrane-transporters.tsv', header=0)

# %%
len(ec_putative_transporters)
# Out:
# 163

# %%
ec_putative_transporters[ec_putative_transporters.duplicated(subset='primary_name')]
# Out:
# Empty DataFrame
# Columns: [primary_name, gene_product]
# Index: []

# %% [markdown]
# # Get db Y-ome transporters

# %%
transporter_summary_html_strings = [
    'is a member of the Multi Antimicrobial Extrusion (MATE) Family of transporters',
]
transporter_strings = [
    'transporter',
    'antiporter',
    'exporter',
    'permease',
    'transport protein',
    'PTS enzyme',
    'efflux pump',
]

# %%
Knowledgebase2 = aliased(Knowledgebase)
KnowledgebaseGene2 = aliased(KnowledgebaseGene)
KnowledgebaseFeature2 = aliased(KnowledgebaseFeature)

# %%
transporters = to_df(
    session.query(
        Gene.locus_id,
        KnowledgebaseGene.primary_name,
        KnowledgebaseFeature.feature,
        Knowledgebase2.name,
        KnowledgebaseGene2.annotation_quality
    )
    .join(KnowledgebaseGene, KnowledgebaseGene.gene_id == Gene.id)
    .join(Knowledgebase, Knowledgebase.id == KnowledgebaseGene.knowledgebase_id)
    .join(KnowledgebaseFeature, KnowledgebaseFeature.knowledgebase_gene_id == KnowledgebaseGene.id)
    .filter(or_(
        and_(
            or_(*[KnowledgebaseFeature.feature.ilike(f'%{x}%') for x in transporter_strings]),
            KnowledgebaseFeature.feature_type.notin_(['summary_html']),
        ),
        and_(
            or_(*[KnowledgebaseFeature.feature.ilike(f'%{x}%') for x in transporter_summary_html_strings]),
            KnowledgebaseFeature.feature_type == 'summary_html',
        ),
    ))
    .join(KnowledgebaseGene2, KnowledgebaseGene2.gene_id == Gene.id)
    .join(Knowledgebase2, Knowledgebase2.id == KnowledgebaseGene2.knowledgebase_id)
    .filter(Knowledgebase2.name == 'Y-ome')
    .filter(KnowledgebaseGene2.annotation_quality == 'low')
)

# %%
transporters_ar = (
    transporters
    .groupby('primary_name')
    .agg(lambda x: list(x))
    .drop(['locus_id', 'name', 'annotation_quality'], axis=1)
)

# %%
len(transporters_ar)
# Out:
# 220

# %%
'ydaN' in transporters_ar.index
# Out:
# False

# %% [markdown]
# # Merge

# %%
merged = transporters_ar.merge(ec_putative_transporters, how='outer', left_index=True, right_on='primary_name')

# %%
merged.head()
# Out:
#                                                feature primary_name  \
# 162  [DUF1656 family putative inner membrane efflux...         aaeX
# 162  [CP4-6 prophage; ABC transporter ATP-binding p...         afuC
# 162  [L-asparagine transporter, transporter, L-aspa...         ansP
# 0    [putative major facilitator superfamily transp...         araJ
# 162  [putative ABC transporter periplasmic binding ...         artI
#
#                                           gene_product
# 162                                                NaN
# 162                                                NaN
# 162                                                NaN
# 0    putative major facilitator superfamily transpo...
# 162                                                NaN

# %%
print(len(merged[~merged.gene_product.isnull()]))
# Out:
# 163

# %%
print(len(merged[~merged.feature.isnull()]))
# Out:
# 220

# %%
len(merged[~merged.gene_product.isnull() & ~merged.feature.isnull()])
# Out:
# 124

# %%
len(merged[merged.gene_product.isnull() & merged.feature.isnull()])
# Out:
# 0

# %% [markdown]
# # set up for export

# %% [markdown]
# NOTES
# - b3682 / glvB excluded as pseudogene
# - b1342 / ydaN evidence from EcoCyc makes this not in the Y-ome "Assay of unpurified protein [Worlock02]"
# - might want to pull some out like b4662 / sgrT

# %%
yome_transporters = (
    transporters
    .groupby('locus_id')
    .agg(lambda x: list(x))
    .drop(['name', 'annotation_quality'], axis=1)
    .reset_index()
    .rename(columns={'locus_id': 'locus_tag', 'feature': 'matched_features'})
)
yome_transporters.primary_name = yome_transporters.primary_name.apply(lambda x: x[0])
yome_transporters.matched_features = yome_transporters.matched_features.apply(lambda x: '; '.join(x))
yome_transporters.head()
# Out:
#   locus_tag primary_name                                   matched_features
# 0     b0007         yaaJ  putative alanine/glycine:cation symporter fami...
# 1     b0045         yaaU  putative major facilitator superfamily transpo...
# 2     b0106         hofC             Protein transport protein HofC homolog
# 3     b0107         hofB             Protein transport protein HofB homolog
# 4     b0127         yadG  putative ABC transporter ATP-binding protein Y...

# %%
yome_transporters.to_csv('../data/yome-transporters.tsv', sep='\t', index=False)
