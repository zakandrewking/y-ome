# %%
import json
import pandas as pd
import numpy as np
from yome import Session
from yome.models import *
from yome.util import to_df, report
import re
from sqlalchemy import or_, and_
from sqlalchemy.orm import aliased
import itertools as it
import seaborn as sns
from collections import Counter

# %%
from mpl_recipes import mpl_setup
# %mpl_setup
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
session = Session()

# %%
def calculate_word_freq(series):
    return None

# %%
# get all features, ignoring 't' and 'f'
features = to_df(
    session.query(
        Gene.locus_id,
        KnowledgebaseGene.primary_name,
        KnowledgebaseFeature.feature_type,
        KnowledgebaseFeature.feature,
    )
    .join(KnowledgebaseGene)
    .join(Knowledgebase)
    .join(KnowledgebaseFeature)
    .filter(KnowledgebaseFeature.feature.notin_(['t', 'f', '']))
    .filter(KnowledgebaseFeature.feature_type.notin_(['summary_html']))
)

# %%
features.head()
# Out:
#   locus_id primary_name  feature_type                               feature
# 0    b2331         smrB   description            putative endonuclease SmrB
# 1    b2331         smrB  product_type                           polypeptide
# 2    b2038         rfbC   description  dTDP-4-dehydrorhamnose 3,5-epimerase
# 3    b2038         rfbC  product_type                                enzyme
# 4    b2038         rfbC     ec_number                              5.1.3.13

# %%
# get y-ome list
yome = to_df(
    session.query(
        Gene.locus_id,
        KnowledgebaseGene.annotation_quality
    )
    .join(KnowledgebaseGene)
    .join(Knowledgebase)
    .filter(Knowledgebase.name == 'Y-ome')
)

# %%
(
    Counter([item for sublist in features.feature.values for item in sublist.split()])
    .most_common()
)
# Out:
# [('of', 14907),
#  ('the', 13775),
#  ('protein', 10341),
#  ('and', 8692),
#  ('(1);', 7682),
#  ('to', 7617),
#  ('+', 7122),
#  ('a', 6996),
#  ('in', 6865),
#  ('is', 5906),
#  ('Chain', 4289),
#  ('putative', 3674),
#  ('from', 3340),
#  ('{}', 3269),
#  ('for', 3152),
#  ('FUNCTION:', 2983),
#  ('by', 2829),
#  ('Null', 2804),
#  ('polypeptide', 2777),
#  ('(1)', 2219),
#  ('The', 2191),
#  ('membrane', 2186),
#  ('binding', 2111),
#  ('an', 2106),
#  ('subunit', 2075),
#  ('family', 1915),
#  ('with', 1911),
#  ('transporter', 1902),
#  ('enzyme;', 1891),
#  ('enzyme', 1876),
#  ('(EC', 1822),
#  ('as', 1821),
#  ('DNA', 1761),
#  ('Not', 1748),
#  ('2', 1726),
#  ('classified', 1716),
#  ('are', 1705),
#  ('(2);', 1622),
#  ('that', 1598),
#  ('CATALYTIC', 1588),
#  ('ACTIVITY:', 1588),
#  ('site', 1535),
#  ('=', 1530),
#  ('be', 1528),
#  ('has', 1492),
#  ('not', 1438),
#  ('function', 1431),
#  ('Putative', 1424),
#  ('strand', 1410),
#  ('mutant', 1403),
#  ('Helix', 1396),
#  ('domain', 1347),
#  ('Beta', 1345),
#  ('→', 1331),
#  ('5', 1330),
#  ('purified', 1310),
#  ('acid', 1267),
#  ('homogeneity', 1263),
#  ('transcriptional', 1251),
#  ('or', 1247),
#  ('Enzyme;', 1183),
#  ('Turn', 1181),
#  ('system', 1179),
#  ('small', 1144),
#  ('ABC', 1128),
#  ('peptide', 1061),
#  ('Sequence', 1058),
#  ('conflict', 1043),
#  ('Assay', 1040),
#  ('regulator', 1040),
#  ('Domain', 1017),
#  ('3', 1001),
#  ('A', 982),
#  ('activity', 946),
#  ('Transmembrane', 927),
#  ('operon', 916),
#  ('also', 902),
#  ('ATP', 900),
#  ('involved', 900),
#  ('but', 898),
#  ('at', 893),
#  ('Inferred', 890),
#  ('(3);', 877),
#  ('transport', 863),
#  ('molecules:', 851),
#  ('complex', 842),
#  ('periplasmic', 832),
#  ('4', 827),
#  ('inner', 826),
#  ('RNA', 826),
#  ('1', 820),
#  ('phenotype', 788),
#  ('its', 788),
#  ('Mutagenesis', 775),
#  ('on', 774),
#  ('sequence', 765),
#  ('synthase', 762),
#  ('which', 762),
#  ('Uncharacterized', 755),
#  ('protein,', 750),
#  ('summary', 741),
#  ('predicted', 736),
#  ('initiation', 733),
#  ('transport;', 731),
#  ('unknown', 705),
#  ('required', 690),
#  ('expression', 687),
#  ('phosphate', 671),
#  ('Active', 668),
#  ('gene', 663),
#  ('cell', 659),
#  ('Erroneous', 643),
#  ('Topological', 638),
#  ('DNA-binding', 637),
#  ('been', 634),
#  ('(extended', 629),
#  ('E.', 627),
#  ('was', 618),
#  ('(2)', 614),
#  ('tRNA', 613),
#  ('ribosomal', 612),
#  ('(4);', 609),
#  ('binds', 607),
#  ('Metal', 599),
#  ('MISCELLANEOUS:', 599),
#  ('reductase', 596),
#  ('may', 593),
#  ('signal', 589),
#  ('Binding', 588),
#  ('H+', 584),
#  ('coli', 584),
#  ('component', 583),
#  ('kinase', 575),
#  ('regulatory', 574),
#  ('have', 573),
#  ('Catalyzes', 570),
#  ('type', 565),
#  ('prophage;', 564),
#  ('it', 553),
#  ('this', 548),
#  ('proteins', 546),
#  ('resistance', 545),
#  ('factor', 541),
#  ('biosynthesis', 540),
#  ('dehydrogenase', 535),
#  ('Transport', 530),
#  ('can', 522),
#  ('Signal', 521),
#  ('aa', 512),
#  ('Nucleotide', 511),
#  ('modification', 510),
#  ('protein;', 507),
#  ('regulator;', 502),
#  ('outer', 500),
#  ('permease', 495),
#  ('Region', 493),
#  ('rRNA', 492),
#  ('host', 490),
#  ('first', 488),
#  ('II', 482),
#  ('growth', 475),
#  ('uncharacterized', 473),
#  ('H2O', 467),
#  ('inference', 465),
#  ('Degradation', 465),
#  ('-', 464),
#  ('N-terminal', 456),
#  ('diphosphate', 451),
#  ('role', 441),
#  ('methionine', 441),
#  ('residue', 438),
#  ('lipoprotein', 429),
#  ('I', 426),
#  ('native', 413),
#  ('Prophage', 413),
#  ('(5);', 407),
#  ('repressor', 405),
#  ('metabolism,', 402),
#  ('C-terminal', 400),
#  ('Phage', 400),
#  ('efflux', 398),
#  ('Energy', 395),
#  ('Amino', 394),
#  ('carbon:', 394),
#  ('ADP', 389),
#  ('Related', 386),
#  ('codon', 383),
#  ('H(2)O', 383),
#  ('prophage', 381),
#  ('form', 381),
#  ('formation', 379),
#  ('2007).', 373),
#  ('during', 367),
#  ('(6);', 363),
#  ('Initiator', 361),
#  ('metabolism:', 360),
#  ('(7);', 358),
#  ('transcription', 357),
#  ('genes', 355),
#  ('assembly', 353),
#  ('oxidoreductase', 350),
#  ('other', 348),
#  ('substrate', 343),
#  ('ATPase', 341),
#  ('PTS', 339),
#  ('Central', 339),
#  ('intermediary', 339),
#  ('compounds', 339),
#  ('both', 337),
#  ('(3)', 337),
#  ('amino', 336),
#  ('into', 336),
#  ('(summary', 333),
#  ('In', 333),
#  ('response', 332),
#  ('does', 330),
#  ('unpurified', 329),
#  ('probably', 328),
#  ('Modified', 327),
#  ('mutants', 325),
#  ('synthesis', 324),
#  ('Involved', 323),
#  ('2009).', 320),
#  ('activator', 318),
#  ('acids,', 316),
#  ('promoter', 316),
#  ('two', 315),
#  ('2006).', 312),
#  ('peptide.', 312),
#  ('regulon.', 311),
#  ('50S', 307),
#  ('biofilm', 305),
#  ('Part', 302),
#  ('start', 299),
#  ('(4)', 298),
#  ('conserved', 296),
#  ('region', 293),
#  ('reduced', 292),
#  ('translation', 292),
#  ('component;', 292),
#  ('when', 291),
#  ('2010).', 287),
#  ('partially-purified', 286),
#  ('export', 283),
#  ('This', 282),
#  ('Transport;', 277),
#  ('polymerase', 276),
#  ('blocked', 275),
#  ('interaction', 275),
#  ('(8);', 274),
#  ('stress', 272),
#  ('It', 272),
#  ('synthesis,', 272),
#  ('Frameshift', 271),
#  ('direct', 269),
#  ('B', 268),
#  ('degradation', 267),
#  ('mRNA', 267),
#  ('2014).', 267),
#  ('chaperone', 265),
#  ('deletion', 265),
#  ('Predicted', 265),
#  ('Human', 263),
#  ('2011).', 262),
#  ('2012).', 262),
#  ('anaerobic', 260),
#  ('structural', 258),
#  ('sugar', 257),
#  ('no', 256),
#  ('Carbon', 255),
#  ('superfamily', 252),
#  ('transfer', 252),
#  ('residues', 252),
#  ('insertion', 251),
#  ('23S', 250),
#  ('Binds', 250),
#  ('electron', 249),
#  ('AMP', 248),
#  ('catalyzes', 248),
#  ('division', 247),
#  ('strain', 247),
#  ('essential', 247),
#  ('functions', 247),
#  ('peptidoglycan', 246),
#  ('respiration', 246),
#  ('part', 246),
#  ('via', 245),
#  ('Surface', 245),
#  ('regulon', 244),
#  ('Biosynthesis', 244),
#  ('chain', 243),
#  ('pyruvate', 243),
#  ('cells', 242),
#  ('2013).', 242),
#  ('two-component', 241),
#  ('cofactors,', 241),
#  ('structures', 241),
#  ('low', 239),
#  ('vitro', 239),
#  ('carriers:', 238),
#  ('30S', 237),
#  ('Probable', 233),
#  ('May', 231),
#  ('assay', 229),
#  ('factor;', 229),
#  ('(11);', 229),
#  ('related', 226),
#  ('(12);', 225),
#  ('across', 224),
#  ('2008).', 224),
#  ('between', 224),
#  ('secretion', 222),
#  ('transposase', 222),
#  ('active', 222),
#  ('domain-containing', 220),
#  ('phosphatase', 220),
#  ('(13);', 220),
#  ('utilization', 219),
#  ('flagellar', 218),
#  ('(10);', 218),
#  ('hydrolase', 217),
#  ('mutation', 215),
#  ('Protein', 215),
#  ('biosynthesis:', 215),
#  ('presence', 215),
#  ('translocation', 214),
#  ('cleavage', 213),
#  ('uptake', 212),
#  ('⇄', 211),
#  ('K-12', 211),
#  ('repair', 210),
#  ('Regulator;', 207),
#  ('Site', 206),
#  ('responsible', 206),
#  ('membrane.', 205),
#  ('beta', 205),
#  ('organic', 204),
#  ('toxin', 203),
#  ('murein', 202),
#  ('transferase', 201),
#  ('Salmonella', 201),
#  ('synthetase', 200),
#  ('ligase', 199),
#  ('genetic', 199),
#  ('ATP-dependent', 199),
#  ('induced', 199),
#  ('regulated', 198),
#  ('one', 198),
#  ('Overexpression', 198),
#  ('Required', 197),
#  ('bond', 197),
#  ('(9);', 197),
#  ('functional', 196),
#  ('pathway', 194),
#  ('specific', 194),
#  ('cryptic', 193),
#  ('histidine', 190),
#  ('cytoplasmic', 190),
#  ('homolog', 189),
#  ('than', 188),
#  ('high', 188),
#  ('reduction', 187),
#  ('expressed', 186),
#  ('shock', 186),
#  ('An', 186),
#  ('group', 186),
#  ('Inner', 185),
#  ('iron', 184),
#  ('replication,', 184),
#  ('sRNA', 184),
#  ('phage', 183),
#  ('toxic', 183),
#  ('divergent', 183),
#  ('2004).', 183),
#  ('Also', 182),
#  ('overexpression', 182),
#  ('lipid', 181),
#  ('Anaerobic', 181),
#  ('cluster', 180),
#  ('acids', 179),
#  ('family.', 179),
#  ('only', 179),
#  ('repair,', 178),
#  ('under', 178),
#  ('analysis', 177),
#  ('alcohols', 176),
#  ('protein)', 175),
#  ('hydrogenase', 174),
#  ('6-phosphate', 174),
#  ('16S', 174),
#  ('protease', 174),
#  ('catabolism', 174),
#  ('Carbohydrates,', 174),
#  ('fimbrial', 173),
#  ('isomerase', 172),
#  ('stationary', 171),
#  ('FNR', 171),
#  ('(6)', 170),
#  ('(5)', 169),
#  ('restriction/modification', 168),
#  ('were', 167),
#  ('E.coli', 167),
#  ('sensitivity', 166),
#  ('due', 165),
#  ('after', 164),
#  ('conversions', 164),
#  ('ATP-binding', 163),
#  ('dual', 163),
#  ('cytochrome', 163),
#  ('using', 163),
#  ('OM', 163),
#  ('found', 162),
#  ('regulation', 161),
#  ('activity.', 161),
#  ('such', 161),
#  ('Probably', 161),
#  ('toxin-antitoxin', 160),
#  ('reaction', 160),
#  ('III', 159),
#  ('synthase)', 158),
#  ('(14);', 158),
#  ('evidence', 157),
#  ('catalytic', 157),
#  ('substrates', 157),
#  ('their', 157),
#  ('bind', 156),
#  ('lyase', 155),
#  ('2003).', 155),
#  ('causes', 155),
#  ('NADH', 154),
#  ('oxidase', 154),
#  ('(Federowicz,', 154),
#  ('S-adenosyl-L-methionine', 153),
#  ('hydrolysis', 153),
#  ('EcoCyc', 153),
#  ('iron-sulfur', 152),
#  ('dehydratase', 152),
#  ('glutathione', 152),
#  ('operon.', 152),
#  ('formate', 151),
#  ('membrane;', 151),
#  ('indicate', 151),
#  ('Met', 151),
#  ('mutations', 151),
#  ('three', 151),
#  ('increases', 151),
#  ('Ribosomal', 151),
#  ('citrate', 150),
#  ('able', 150),
#  ('methyltransferase', 149),
#  ('initial', 149),
#  ('Qin', 148),
#  ('inhibitor', 148),
#  ('Is', 148),
#  ('Reaction', 147),
#  ('intact', 147),
#  ('removed', 147),
#  ('paralogs.', 147),
#  ('replication', 146),
#  ('large', 146),
#  ('ArcA', 146),
#  ('proteins,', 146),
#  ('homologous', 146),
#  ('pattern', 145),
#  ('phosphotransferase', 145),
#  ('all', 145),
#  ('nucleoside', 144),
#  ('pump', 144),
#  ('known', 144),
#  ('unknown;', 144),
#  ('multidrug', 143),
#  ('reductase,', 143),
#  ('production', 143),
#  ('alpha', 143),
#  ('variant', 143),
#  ('spectrometry', 143),
#  ('carrier', 142),
#  ('antitoxin', 142),
#  ('metabolism', 142),
#  ('2005).', 142),
#  ('/', 141),
#  ('cysteine', 141),
#  ('Mass', 141),
#  ('sensory', 140),
#  ('structure', 140),
#  ('use', 140),
#  ('5-phosphate', 139),
#  ('dehydrogenase,', 139),
#  ('fatty', 139),
#  ('thiamine', 139),
#  ('pseudogene,', 139),
#  ('shown', 139),
#  ('phosphate.', 139),
#  ('IS,', 138),
#  ('phage,', 138),
#  ('Tn;', 138),
#  ('based', 137),
#  ('experiment', 137),
#  ('fragment', 137),
#  ('specificity', 137),
#  ('vivo', 137),
#  ('defective', 136),
#  ('some', 136),
#  ('confers', 136),
#  ('Function', 134),
#  ('subunit;', 134),
#  ('Can', 134),
#  ('CoA', 133),
#  ('carbon', 133),
#  ('against', 133),
#  ('addition', 133),
#  ('Rac', 132),
#  ('nitrogen', 132),
#  ('MS', 132),
#  ('increased', 132),
#  ('although', 132),
#  ('nucleotide', 131),
#  ('functions;', 131),
#  ('levels', 131),
#  ('contains', 131),
#  ('acceptor', 130),
#  ('glycine', 130),
#  ('member', 130),
#  ('requires', 130),
#  ('Pool,', 130),
#  ('multipurpose', 130),
#  ('(15);', 130),
#  ('transposon', 129),
#  ('RNase', 129),
#  ('RpoS', 129),
#  ('protein.', 129),
#  ('suppressor', 128),
#  ('see', 128),
#  ('transmembrane', 127),
#  ('reported', 127),
#  ('thus', 127),
#  ('double', 126),
#  ('position', 126),
#  ('masses', 126),
#  ('ribosome', 125),
#  ('major', 125),
#  ('conditions', 125),
#  ('more', 125),
#  ('including', 125),
#  ('helicase', 124),
#  ('C', 124),
#  ('transporter,', 124),
#  ('Cell', 124),
#  ('phase', 124),
#  ('(Maillet,', 124),
#  ('Natural', 124),
#  ('triphosphate', 123),
#  ('DLP12', 123),
#  ('oxidative', 123),
#  ('Transcriptional', 123),
#  ('Murein', 123),
#  ('Has', 123),
#  ('intermediate', 123),
#  ('(16);', 123),
#  ('HTH-type', 123),
#  ('sigma', 122),
#  ('ribonucleotide', 122),
#  ('channel', 122),
#  ('Transposon-related', 122),
#  ('extrachromosomal;', 122),
#  ('oxidized', 121),
#  ('peptidase', 121),
#  ('pseudogene', 121),
#  ('Although', 120),
#  ('complementation', 119),
#  ('aldolase', 119),
#  ('maturation', 119),
#  ('synthase,', 119),
#  ('amines', 119),
#  ('{ECO:0000250}.', 119),
#  ('sulfur', 118),
#  ('conversion', 118),
#  ('statement', 117),
#  ('CP4-6', 117),
#  ('then', 117),
#  ('GTP', 116),
#  ('hydrogen', 116),
#  ('energy', 116),
#  ('bacterial', 116),
#  ('phosphorylation', 116),
#  ('possibly', 116),
#  ('class', 115),
#  ('activated', 115),
#  ('heme', 115),
#  ('import', 115),
#  ('unknown,', 115),
#  ('nitrate', 114),
#  ('zinc', 114),
#  ('these', 114),
#  ('Global', 114),
#  ('stop', 114),
#  ('lipopolysaccharide', 113),
#  ('e14', 113),
#  ("3'", 113),
#  ('acts', 113),
#  ('step', 113),
#  ('GTPase', 112),
#  ('activates', 112),
#  ('defect', 112),
#  ('could', 112),
#  ('activity,', 112),
#  ('regulates', 112),
#  ('system.', 112),
#  ('NAD(+)', 112),
#  ('S-adenosyl-L-homocysteine', 111),
#  ('play', 111),
#  ('receptor', 110),
#  ('through', 110),
#  ('proteins.', 110),
#  ('author', 109),
#  ('aerobic', 109),
#  ('confirm', 109),
#  ("5'", 108),
#  ('weak', 108),
#  ('upstream', 108),
#  ('Cations', 108),
#  ('(Pfam', 108),
#  ('core', 107),
#  ('indicating', 107),
#  ('proton', 107),
#  ('strains', 107),
#  ('(12)', 107),
#  ('intracellular', 106),
#  ('subunit,', 106),
#  ('ring', 105),
#  ('directly', 105),
#  ('fused', 104),
#  ('semialdehyde', 104),
#  ('release', 103),
#  ('disulfide', 103),
#  ('acetyl-CoA', 103),
#  ('antibiotic', 103),
#  ('CP4-57', 103),
#  ('elongation', 103),
#  ('SAM-dependent', 103),
#  ('target', 103),
#  ('since', 103),
#  ('Structural', 103),
#  ('system,', 102),
#  ('Could', 102),
#  ('2002).', 101),
#  ('(17);', 101),
#  ('L-glutamate', 100),
#  ('NADPH', 100),
#  ('exporter', 100),
#  ('3-phosphate', 100),
#  ('phosphodiesterase', 100),
#  ('motility', 100),
#  ('inhibits', 100),
#  ('lambda', 100),
#  ('Outer', 100),
#  ('domain.', 100),
#  ('cyclase', 99),
#  ('either', 99),
#  ('because', 99),
#  ('Disulfide', 99),
#  ('1-phosphate', 98),
#  ('inhibition', 98),
#  ('cofactor', 98),
#  ('phenotype;', 98),
#  ('domains', 98),
#  ('act', 98),
#  ('second', 98),
#  ('proposed', 98),
#  ('Acts', 98),
#  ('Traceable', 97),
#  ('human', 97),
#  ('peroxide', 97),
#  ('Fe-S', 97),
#  ('general', 97),
#  ('lysine', 97),
#  ('identified', 97),
#  ('coenzyme', 96),
#  ('sensor', 96),
#  ('sacculus,', 96),
#  ('four', 96),
#  ('methyltransferase,', 96),
#  ('used', 96),
#  ('diguanylate', 95),
#  ('element', 95),
#  ('succinate', 95),
#  ('well', 95),
#  ('adenine', 94),
#  ('Major', 94),
#  ('bound', 94),
#  ('2-oxoglutarate', 93),
#  ('leader', 93),
#  ('single', 93),
#  ('CRISPR', 93),
#  ('family,', 93),
#  ('remnant', 93),
#  ('present', 93),
#  ('characterized', 93),
#  ('Lipidation', 93),
#  ('colanic', 92),
#  ('physiological', 92),
#  ('Motif', 92),
#  ('oxidoreductase,', 91),
#  ('↔', 91),
#  ('ferric', 91),
#  ('associated', 91),
#  ('affinity', 91),
#  ('putrescine', 90),
#  ('phosphorylated', 90),
#  ('decarboxylase', 90),
#  ('heat', 90),
#  ('FtsZ', 90),
#  ('activation', 90),
#  ('effect', 90),
#  ('pyrophosphate', 89),
#  ('modified', 89),
#  ('Pseudogene,', 89),
#  ('induction', 89),
#  ('forms', 89),
#  ('Pseudogene', 89),
#  ('(7)', 89),
#  ('serine', 88),
#  ('various', 88),
#  ('endonuclease', 87),
#  ('so', 87),
#  ('likely', 87),
#  ('source', 87),
#  ('Factor;', 87),
#  ('genes.', 87),
#  ('containing', 86),
#  ('aldehyde', 86),
#  ('fusion', 86),
#  ('positive', 86),
#  ('Superfamily', 86),
#  ('repressed', 86),
#  ('multicopy', 86),
#  ('formation.', 86),
#  ('important', 86),
#  ('repeat', 85),
#  ('product', 85),
#  ('membrane-anchored', 85),
#  ('Flagellar', 85),
#  ('(By', 85),
#  ('similarity).', 85),
#  ('short', 84),
#  ('operon,', 84),
#  ('Phenotype;', 84),
#  ('results', 84),
#  ('Macromolecule', 84),
#  ('redox', 83),
#  ('1)', 83),
#  ('(10)', 83),
#  ('complex,', 82),
#  ('encodes', 82),
#  ('level', 82),
#  ('TrxA', 82),
#  ('(Kumar,', 82),
#  ('vitro,', 82),
#  ('cellulose', 81),
#  ('arginine', 81),
#  ('oxidation', 81),
#  ('nucleotides', 81),
#  ('sensitive', 81),
#  ('stimulates', 81),
#  ('Facilitator', 81),
#  ('plasmid', 81),
#  ('reconstruction,', 81),
#  ('oxygen', 80),
#  ('chemotaxis', 80),
#  ('pyrimidine', 80),
#  ('signaling', 80),
#  ('control', 80),
#  ('membrane-bound', 80),
#  ('[Siekevitz81]', 80),
#  ('Cys', 80),
#  ('absence', 80),
#  ('downstream', 80),
#  ('extracellular', 80),
#  ('(8)', 80),
#  ('acetyltransferase', 79),
#  ('computational', 79),
#  ('deaminase', 79),
#  ('recombination', 79),
#  ('glucose', 79),
#  ('very', 79),
#  ('similar', 79),
#  ('Aerobic', 79),
#  ('called', 79),
#  ('gene.', 79),
#  ('A)', 79),
#  ('protein]', 78),
#  ('NAD+', 78),
#  ("5'-phosphate", 78),
#  ('dependent', 78),
#  ('Purine', 78),
#  ('leads', 78),
#  ('subunits', 78),
#  ('controls', 78),
#  ('reversible', 78),
#  ('NADH.', 77),
#  ('3.6.3.-', 76),
#  ('E', 76),
#  ('antiporter', 76),
#  ('fumarate', 76),
#  ('2001).', 76),
#  ('plays', 76),
#  ('LPS', 76),
#  ('purine', 75),
#  ('adhesin', 75),
#  ('polysaccharide', 75),
#  ('while', 75),
#  ('transglycosylase', 74),
#  ('suppresses', 74),
#  ('precursor', 74),
#  ('effects', 74),
#  ('mechanism', 74),
#  ('acyl', 73),
#  ('reducing', 73),
#  ('ubiquinone', 73),
#  ('probable', 73),
#  ('c-di-GMP', 73),
#  ('inactive', 73),
#  ('IIB', 73),
#  ('needed', 73),
#  ('N-terminus', 73),
#  ('verified', 73),
#  ('leading', 73),
#  ('(20);', 73),
#  ('reductase)', 73),
#  ('biogenesis', 72),
#  ('interacts', 72),
#  ('glutamine', 72),
#  ('symporter', 72),
#  ('IS1', 72),
#  ('synthase;', 72),
#  ('bp', 72),
#  ('Proteins', 72),
#  ('(18);', 72),
#  ('H(2)O.', 72),
#  ('bifunctional', 71),
#  ('IV', 71),
#  ('lipoprotein,', 71),
#  ('allele', 71),
#  ('yield', 71),
#  ('several', 71),
#  ('donor', 71),
#  ('NADP+', 70),
#  ('acetate', 70),
#  ('glutamate', 70),
#  ('pseudouridine', 70),
#  ('4Fe-4S', 70),
#  ('global', 70),
#  ('Drug/analog', 70),
#  ('Electron', 70),
#  ('transport.', 70),
#  ('observed', 70),
#  ('Fatty', 70),
#  ('overproduction', 70),
#  ('I)', 70),
#  ('induces', 70),
#  ('different', 70),
#  ('L-methionine', 69),
#  ('nuclease', 69),
#  ('enterobactin', 69),
#  ('cold', 69),
#  ('end', 69),
#  ('within', 69),
#  ('length', 69),
#  ('suggesting', 69),
#  ('codons', 69),
#  ('sites', 69),
#  ('survival', 69),
#  ('formed', 69),
#  ('produce', 69),
#  ('2)', 69),
#  ('H2O[periplasm]', 68),
#  ('porin', 68),
#  ('frameshift', 68),
#  ('own', 68),
#  ('wall', 68),
#  ('70S', 68),
#  ('aminotransferase', 67),
#  ('grow', 67),
#  ('cycle', 67),
#  ('(MFS).', 67),
#  ('1998).', 67),
#  ('enzymes', 67),
#  ('belongs', 67),
#  ('many', 67),
#  ('specifically', 67),
#  ('(19);', 67),
#  ('cyclic', 66),
#  ('fimbrial-like', 66),
#  ('negatively', 66),
#  ('damage', 66),
#  ('coupling', 66),
#  ('ribosomes', 66),
#  ('NADP(+)', 66),
#  ('single-stranded', 65),
#  ('chromosome', 65),
#  ('O-antigen', 65),
#  ('efficient', 65),
#  ('members', 65),
#  ('activities', 65),
#  ('peptides,', 65),
#  ('adjacent', 65),
#  ('ammonium', 64),
#  ('maltose', 64),
#  ('FMN', 64),
#  ('mature', 64),
#  ('potassium', 64),
#  ('copper', 64),
#  ('IIA', 64),
#  ('activity;', 64),
#  ('Aminoacyl', 64),
#  ('synthetases,', 64),
#  ('operons', 64),
#  ('might', 64),
#  ('B.', 64),
#  ('constitute', 64),
#  ('appears', 64),
#  ('enhanced', 63),
#  ('thioredoxin', 63),
#  ('free', 63),
#  ('aromatic', 63),
#  ('flavoprotein', 63),
#  ('cognate', 63),
#  ('if', 63),
#  ('allows', 63),
#  ('represses', 63),
#  ('same', 63),
#  ('medium', 63),
#  ('transporter;', 63),
#  ('previously', 63),
#  ('regulate', 63),
#  ('transposition', 63),
#  ('limited', 63),
#  ('adhesion', 63),
#  ('electrons', 63),
#  ('usher', 62),
#  ('acyl-CoA', 62),
#  ('antisense', 62),
#  ('starvation', 62),
#  ('tail', 62),
#  ('IIC', 62),
#  ('common', 62),
#  ('swarming', 62),
#  ('lethal', 62),
#  ('renamed', 62),
#  ('mediates', 62),
#  ('necessary', 62),
#  ('most', 62),
#  ('NADPH.', 62),
#  ('(11)', 62),
#  ('Plays', 62),
#  ('CO2', 61),
#  ('[1]', 61),
#  ('exonuclease', 61),
#  ('base', 61),
#  ('quinone', 61),
#  ('B)', 61),
#  ('homolog,', 61),
#  ('moiety', 61),
#  ('lambdoid', 61),
#  ('xanthine', 60),
#  ('Automated', 60),
#  ('NAD(P)-binding', 60),
#  ('termination', 60),
#  ('20', 60),
#  ('there', 60),
#  ('conditions.', 60),
#  ('protection', 60),
#  ('homologs', 60),
#  ('K-12.', 60),
#  ('[Includes:', 60),
#  ('binding-protein-dependent', 60),
#  ('nascent', 59),
#  ('alcohol', 59),
#  ('L-serine', 59),
#  ('methyl', 59),
#  ('capsule', 59),
#  ('V', 59),
#  ('reactive', 59),
#  ('regulator,', 59),
#  ('processing', 59),
#  ('pH', 59),
#  ('II)', 59),
#  ('gene,', 59),
#  ('EF-Tu', 59),
#  ('hydrolyzes', 59),
#  ('catalyze', 59),
#  ('available):[(RrsA)(RpsA)(RpsB)(RpsC)(RpsD)(RpsE)(RpsF)(RpsG)(RpsH)(RpsI)(RpsJ)(RpsK)(RpsL)(RpsM)(RpsN)(RpsO)(RpsP)(RpsQ)(RpsR)(RpsS)(RpsT)(RpsU)(Sra)][(RrlA)(RrfA)(RplA)(RplB)(RplC)(RplD)(RplE)(RplF)([RplJ][(RplL)2]2)(RplI)(RplK)(RplM)(RplN)(RplO)(RplP)(RplQ)(RplR)(RplS)(RplT)(RplU)(RplV)(RplW)(RplX)(RplY)(RpmA)(RpmB)(RpmC)(RpmD)(RpmE)(RpmF)(RpmG)(RpmH)(RpmI)(RpmJ)]',
#   58),
#  ('arabinose', 58),
#  ('ribose', 58),
#  ('accessory', 58),
#  ('translocase', 58),
#  ('SAM', 58),
#  ('pair', 58),
#  ('terminal', 58),
#  ('ubiquinol', 58),
#  ...]
