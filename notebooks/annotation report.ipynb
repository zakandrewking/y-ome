# %% [markdown]
# # Generate a report of the database features for a given gene

# %%
from yome import Session
from yome.util import report
session = Session()

# %%
report(
    session, 
    'b0139', # gene locus tag or primary name
)
# Out:
# locus_id        b0139
# primary_name     htrE
# Name: 0, dtype: object
# <style  type="text/css" >
#     #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row0_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row1_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row2_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row3_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row4_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row5_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row6_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row7_col0 {
#             text-align:  left;
#         }    #T_05f8a3e8_e922_11e8_9e8f_406c8fbb9e82row8_col0 {
#             text-align:  left;
# ...
