# %% [markdown]
# https://docs.google.com/document/d/1iHS3AkmFTBpOgzQhMffH-rxfxiCenWmmkn7BZz4oXoM/edit

# %%
import pandas as pd

# %% [markdown]
# # Proteomics
# https://www.ncbi.nlm.nih.gov/pubmed/26641532

# %%
counts = pd.read_table('../data/nbt-schmidt/counts.tsv')

# %%
counts.head()
# Out:
#    Unnamed: 0 Uniprot Accession  \
# 0           0            P0A8T7
# 1           1            P0A8V2
# 2           2            P36683
# 3           3            P15254
# 4           4            P09831
#
#                                          Description  Gene  \
# 0  DNA-directed RNA polymerase subunit beta' OS=E...  rpoC
# 1  DNA-directed RNA polymerase subunit beta OS=Es...  rpoB
# 2  Aconitate hydratase 2 OS=Escherichia coli (str...  acnB
# 3  Phosphoribosylformylglycinamidine synthase OS=...  purL
# 4  Glutamate synthase [NADPH] large chain OS=Esch...  gltB
#
#    Peptides.used.for.quantitation  Confidence.score  Molecular weight (Da)  \
# 0                              91           6045.53            155045.0080
# 1                              89           5061.29            150520.2758
# 2                              67           4505.67             93420.9457
# 3                              65           4277.71            141295.8984
# 4                              64           4111.74            163176.3153
#
#    Dataset  Glucose     LB    ...     Stationary phase 1 day  \
# 0        2     2779   7164    ...                       1735
# 1        2     3957   8888    ...                       2379
# 2        2     7596  16600    ...                        933
# 3        2     2456    821    ...                        618
# 4        2     2859    604    ...                        230
#
#    Stationary phase 3 days  Osmotic-stress glucose  42°C glucose  pH6 glucose  \
# 0                     1907                    2248          3985         3339
# 1                     2227                    3254          4923         4032
# 2                      756                    2815          4842         4649
# 3                      735                    1318          1885         1708
# 4                      183                     834          2979         2723
#
#    Xylose  Mannose  Galactose   Succinate  Fructose
# 0  3632.0   3401.0        2258       2764    4517.0
# 1  4437.0   4143.0        2820       3855    5269.0
# 2  6697.0  16517.0       12875      19547    8782.0
# 3  1721.0   1764.0        1570       1913    2406.0
# 4  2496.0   2079.0        1398       1553    3858.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # EcoFit

# %% [markdown]
# For More Information about strains, fitness, specphes (specific phenotype), and the t-test like statistic. Raw data is here too:
# http://genomics.lbl.gov/supplemental/bigfit/html/Keio/
#
# Full Publication: https://www.biorxiv.org/content/early/2016/08/31/072470
#
# Run the jupyter notebook to view key plots and view code used to generate them.
#
# fit_logratios_good.tab is tab-separated and has the fitness data for all strains across all conditions
#
# expsUsed.txt is tab-separated and has metadata for all of the experimental condtions
#
# key_phen.txt is tab-separated and has fitness data for all of the strain-condition pairs that were determined to be specific phenotypes (specphe)

# %% [markdown]
# # SauerMet
